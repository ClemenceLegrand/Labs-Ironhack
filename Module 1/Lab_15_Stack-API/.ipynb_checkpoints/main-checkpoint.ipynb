# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
pip install stackapi
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for stackapi: filename=StackAPI-0.2.0-py3-none-any.whl size=5843 sha256=fd692063b37c6465e05ff09a9bdf0070229bdb563fd19ee7ea0895ce1658b963
#   Stored in directory: /Users/clemence/Library/Caches/pip/wheels/de/58/fe/8bab7cf44d8b0bf32e46f1715df2ba8c97d475de95a20985ac
# Successfully built stackapi
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from stackapi import StackAPI

# %%
from datetime import datetime

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', since=datetime(2022,12,26))
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 294,
#  'total': 0,
#  'items': [{'tags': ['python', 'keras'],
#    'owner': {'reputation': 329,
#     'user_id': 6089166,
#     'user_type': 'registered',
#     'accept_rate': 75,
#     'profile_image': 'https://www.gravatar.com/avatar/6bdde478a4ea6e64e27bd05f20509d11?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'sazearte',
#     'link': 'https://stackoverflow.com/users/6089166/sazearte'},
#    'is_answered': False,
#    'view_count': 25,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1674728826,
#    'creation_date': 1674719790,
#    'question_id': 75243418,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75243418/keras-predict-which-player-is-the-strongest-instead-of-player1-will-win',
#    'title': 'Keras, predict which player is the strongest (instead of player1 will win?)'},
#   {'tags': ['linux', 'ansible'],
# ...

# %%
#try to extract only the questions in a list
items=questions["items"]
print(items)
# Out:
# [{'tags': ['python', 'keras'], 'owner': {'reputation': 329, 'user_id': 6089166, 'user_type': 'registered', 'accept_rate': 75, 'profile_image': 'https://www.gravatar.com/avatar/6bdde478a4ea6e64e27bd05f20509d11?s=256&d=identicon&r=PG&f=1', 'display_name': 'sazearte', 'link': 'https://stackoverflow.com/users/6089166/sazearte'}, 'is_answered': False, 'view_count': 25, 'answer_count': 1, 'score': 0, 'last_activity_date': 1674728826, 'creation_date': 1674719790, 'question_id': 75243418, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/75243418/keras-predict-which-player-is-the-strongest-instead-of-player1-will-win', 'title': 'Keras, predict which player is the strongest (instead of player1 will win?)'}, {'tags': ['linux', 'ansible'], 'owner': {'reputation': 1, 'user_id': 16295749, 'user_type': 'registered', 'profile_image': 'https://lh6.googleusercontent.com/-lhdUwlIbe9s/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucklxgZzK3pKe5-9X2OYWJhMeOGYbw/s96-c/photo.jpg?sz=256', 'disp
# ...

# %%
list_question=[d['title'] for d in items]
list_question
# Out:
# ['Keras, predict which player is the strongest (instead of player1 will win?)',
#  'how to pass value to variable in list, to pick one by one using command &quot;ansible-playbook test.yml --extra-var variable1=ntpd,crond,sysconf&quot;',
#  '(Docxtpl) How to add conditional statement to a value in a existing template',
#  'How to get the last datetime of each car which value is `repair`?',
#  'How to get array/object number value in postgreSQL?',
#  'VSCode Intellisense with PyQt5',
#  'How to remove duplicated dependencies code from webpack bundle?',
#  'Add date + time variable to results files',
#  'Junit Test Pass even when the method called inside may fail',
#  'Slide Galllery not visible with React.js TailwindCss',
#  'how do I change the network state over ADB?',
#  'How can I replace part of matrix with a new matrix',
#  'How to read one txt file as separate documents to parse through in Python?',
#  'Psql queries have become very slow after upgrading from 11.18 to 14.6',
# ...

# %%
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('answers', since=datetime(2022,12,26))
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 288,
#  'total': 0,
#  'items': [{'owner': {'reputation': 1,
#     'user_id': 10774412,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a04f90f04a42bc6aac2a418654f4e33c?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Kubilay Cakmak',
#     'link': 'https://stackoverflow.com/users/10774412/kubilay-cakmak'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1674728903,
#    'creation_date': 1674728903,
#    'answer_id': 75244873,
#    'question_id': 75244757,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 12708,
#     'user_id': 309798,
#     'user_type': 'registered',
#     'accept_rate': 78,
#     'profile_image': 'https://www.gravatar.com/avatar/2e31f98a4a93544e42cc8581483a5787?s=256&d=identicon&r=PG',
#     'display_name': 'Amir Saniyan',
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
SITE = StackAPI('stackoverflow')
question_most_voted = SITE.fetch('questions', fromdate=datetime(2023,1,25), todate=datetime(2023,1,26), min=5, tagged='python', sort='votes')
question_most_voted
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 280,
#  'total': 0,
#  'items': [{'tags': ['python', 'python-3.x', 'data-science', 'openai', 'jina'],
#    'owner': {'reputation': 93,
#     'user_id': 20550057,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/f8983e72b552c2f0594e2667754fc588?s=256&d=identicon&r=PG',
#     'display_name': 'Shaiming Yen',
#     'link': 'https://stackoverflow.com/users/20550057/shaiming-yen'},
#    'is_answered': False,
#    'view_count': 29,
#    'answer_count': 0,
#    'score': 7,
#    'last_activity_date': 1674661812,
#    'creation_date': 1674661666,
#    'last_edit_date': 1674661812,
#    'question_id': 75236433,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75236433/runtimeerror-clamp-min-cpu-not-implemented-for-half',
#    'title': 'RuntimeError: &quot;clamp_min_cpu&quot; not implemented for &quot;Half&quot;'}]}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
SITE = StackAPI('stackoverflow')
specific_answers = SITE.fetch('answers', ids=[6784, 6473])
specific_answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 276,
#  'total': 0,
#  'items': [{'owner': {'reputation': 30551,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=256&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5'}]}
